# %%
import pandas as pd

song_df = pd.read_csv("song_dataset.csv")
print("columns: ", song_df.columns)
song_df.head(30)
# Out:
# /var/folders/tl/4hmmdc557x30002rq60f6vfm0000gn/T/ipykernel_33243/3581987640.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# columns:  Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')
#     Unnamed: 0                track_id                               artists  \
# 0            0  5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1            1  4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2            2  1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3            3  6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4            4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5            5  01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6            6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7            7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8            8  0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9            9  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
# 10          10  4mzP5mHkRvGxdhdGdAH7EJ                          Zack Tabudlo
# 11          11  5ivF4eQBqJiVL5IAE9jRyl                            Jason Mraz
# 12          12  4ptDJbJl35d7gQfeNteBwp                              Dan Berk
# 13          13  0X9MxHR1rTkEHDjp95F2OO                         Anna Hamilton
# 14          14  4LbWtBkN82ZRhz9jqzgrb3              Chord Overstreet;Deepend
# 15          15  1KHdq8NK9QxnGjdXb55NiG                           Landon Pigg
# 16          16  6xKeQgzfjixSUld14qUezm                  Andrew Foy;Renee Foy
# 17          17  4Yo0igmcoNyat1secaH0OD                  Andrew Foy;Renee Foy
# 18          18  2qLMf6TuEC3ruGJg4SMMN6             Jason Mraz;Colbie Caillat
# 19          19  6CgNoAbFJ4Q4Id4EjtbXlC               Boyce Avenue;Bea Miller
# 20          20  3S0OXQeoh0w6AY8WQVckRW                            Jason Mraz
# 21          21  210JCw2LbYD4YIs8GiZ9iP            Boyce Avenue;Jennel Garcia
# 22          22  5TvE3pk05pyFIGdSY9j4DJ  A Great Big World;Christina Aguilera
# 23          23  0BUuuEvNa5T4lMaewyiudB                            Jason Mraz
# 24          24  3Hn3LfhrQOaKihdCibJsTs                            Jason Mraz
# 25          25  6D33wCKzWtNEgOovgeVJ7r                            Jason Mraz
# 26          26  5IfCZDRXZrqZSm8AwE44PG                            Jason Mraz
# 27          27  0dzKBptH2P5j5a0MifBMwM                            Jason Mraz
# 28          28  5QAMZTM5cmLg3fHX9ZbTZi                            Jason Mraz
# 29          29  2qESE1ZeWly7I3YjyTXmXh                            Jason Mraz
#
#                                            album_name  \
# 0                                              Comedy
# 1                                    Ghost (Acoustic)
# 2                                      To Begin Again
# 3   Crazy Rich Asians (Original Motion Picture Sou...
# 4                                             Hold On
# 5                                Days I Will Remember
# 6                         Is There Anybody Out There?
# 7                 We Sing. We Dance. We Steal Things.
# 8                 We Sing. We Dance. We Steal Things.
# 9                                              Hunger
# 10                                            Episode
# 11                         Love Is a Four Letter Word
# 12                                               Solo
# 13                                           Bad Liar
# 14                                    Hold On (Remix)
# 15                                  The Boy Who Never
# 16                              ily (i love you baby)
# 17                                        At My Worst
# 18                We Sing. We Dance. We Steal Things.
# 19                             Cover Sessions, Vol. 4
# 20                We Sing. We Dance. We Steal Things.
# 21                             Cover Sessions, Vol. 3
# 22  Is There Anybody Out There? - Track by Track C...
# 23                                      Coffee Moment
# 24                       Human - Best Adult Pop Tunes
# 25                                   Mellow Adult Pop
# 26                              Holly Jolly Christmas
# 27                 Feeling Good - Adult Pop Favorites
# 28                                     Christmas Time
# 29                             Perfect Christmas Hits
#
#                           track_name  popularity  duration_ms  explicit  \
# 0                             Comedy          73       230666     False
# 1                   Ghost - Acoustic          55       149610     False
# 2                     To Begin Again          57       210826     False
# 3         Can't Help Falling In Love          71       201933     False
# 4                            Hold On          82       198853     False
# 5               Days I Will Remember          58       214240     False
# 6                      Say Something          74       229400     False
# 7                          I'm Yours          80       242946     False
# 8                              Lucky          74       189613     False
# 9                             Hunger          56       205594     False
# 10              Give Me Your Forever          74       244800     False
# 11                   I Won't Give Up          69       240165     False
# 12                              Solo          52       198712     False
# 13                          Bad Liar          62       248448     False
# 14                   Hold On - Remix          56       188133     False
# 15  Falling in Love at a Coffee Shop          58       244986     False
# 16             ily (i love you baby)          56       129750     False
# 17                       At My Worst          54       169728     False
# 18                             Lucky          68       189613     False
# 19                        Photograph          67       260186     False
# 20                         I'm Yours          75       242946     False
# 21                            Demons          63       174174     False
# 22                     Say Something          70       229400     False
# 23                  93 Million Miles           0       216386     False
# 24                          Unlonely           0       231266     False
# 25                        Bella Luna           1       302346     False
# 26                 Winter Wonderland           0       131760     False
# 27                    If It Kills Me           0       273653     False
# 28                 Winter Wonderland           0       131760     False
# 29                 Winter Wonderland           0       131760     False
#
#     danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0          0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1          0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2          0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3          0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4          0.618  0.4430  ...    -9.681     1       0.0526        0.4690
# 5          0.688  0.4810  ...    -8.807     1       0.1050        0.2890
# 6          0.407  0.1470  ...    -8.822     1       0.0355        0.8570
# 7          0.703  0.4440  ...    -9.331     1       0.0417        0.5590
# 8          0.625  0.4140  ...    -8.700     1       0.0369        0.2940
# 9          0.442  0.6320  ...    -6.770     1       0.0295        0.4260
# 10         0.627  0.3630  ...    -8.127     1       0.0291        0.2790
# 11         0.483  0.3030  ...   -10.058     1       0.0429        0.6940
# 12         0.489  0.3140  ...    -9.245     0       0.0331        0.7490
# 13         0.691  0.2340  ...    -6.441     1       0.0285        0.7770
# 14         0.755  0.7800  ...    -6.084     1       0.0327        0.1240
# 15         0.489  0.5610  ...    -7.933     1       0.0274        0.2000
# 16         0.706  0.1120  ...   -18.098     1       0.0391        0.8270
# 17         0.795  0.0841  ...   -18.090     0       0.0461        0.7420
# 18         0.625  0.4140  ...    -8.700     1       0.0369        0.2940
# 19         0.717  0.3200  ...    -8.393     1       0.0283        0.8300
# 20         0.703  0.4440  ...    -9.331     1       0.0417        0.5590
# 21         0.678  0.3510  ...    -8.654     1       0.0266        0.7470
# 22         0.407  0.1470  ...    -8.822     1       0.0355        0.8570
# 23         0.572  0.4540  ...   -10.286     1       0.0258        0.4770
# 24         0.796  0.6670  ...    -4.831     0       0.0392        0.3810
# 25         0.755  0.4540  ...    -9.609     0       0.0352        0.7570
# 26         0.620  0.3090  ...    -9.209     1       0.0495        0.7880
# 27         0.633  0.4290  ...    -6.784     0       0.0381        0.0444
# 28         0.620  0.3090  ...    -9.209     1       0.0495        0.7880
# 29         0.620  0.3090  ...    -9.209     1       0.0495        0.7880
#
#     instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0           0.000001    0.3580   0.7150   87.917               4     acoustic
# 1           0.000006    0.1010   0.2670   77.489               4     acoustic
# 2           0.000000    0.1170   0.1200   76.332               4     acoustic
# 3           0.000071    0.1320   0.1430  181.740               3     acoustic
# 4           0.000000    0.0829   0.1670  119.949               4     acoustic
# 5           0.000000    0.1890   0.6660   98.017               4     acoustic
# 6           0.000003    0.0913   0.0765  141.284               3     acoustic
# 7           0.000000    0.0973   0.7120  150.960               4     acoustic
# 8           0.000000    0.1510   0.6690  130.088               4     acoustic
# 9           0.004190    0.0735   0.1960   78.899               4     acoustic
# 10          0.000000    0.0928   0.3010   99.905               4     acoustic
# 11          0.000000    0.1150   0.1390  133.406               3     acoustic
# 12          0.000000    0.1130   0.6070  124.234               4     acoustic
# 13          0.000000    0.1200   0.2090   87.103               4     acoustic
# 14          0.000028    0.1210   0.3870  120.004               4     acoustic
# 15          0.000046    0.1790   0.2380   83.457               3     acoustic
# 16          0.000004    0.1250   0.4140  110.154               4     acoustic
# 17          0.000012    0.0853   0.6090   91.803               4     acoustic
# 18          0.000000    0.1510   0.6690  130.088               4     acoustic
# 19          0.000000    0.1070   0.3220  107.946               4     acoustic
# 20          0.000000    0.0973   0.7120  150.960               4     acoustic
# 21          0.000000    0.3550   0.5690   90.032               4     acoustic
# 22          0.000003    0.0913   0.0765  141.284               3     acoustic
# 23          0.000014    0.0974   0.5150  140.182               4     acoustic
# 24          0.000000    0.2210   0.7540   97.988               4     acoustic
# 25          0.000000    0.2360   0.3300  120.060               4     acoustic
# 26          0.000000    0.1460   0.6640  145.363               4     acoustic
# 27          0.000000    0.1320   0.5200  143.793               4     acoustic
# 28          0.000000    0.1460   0.6640  145.363               4     acoustic
# 29          0.000000    0.1460   0.6640  145.363               4     acoustic
#
# [30 rows x 21 columns]

# %%
song_df_numerical = song_df[['duration_ms', 'explicit', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
       'track_genre', "time_signature"]]

song_df_numerical.info()
song_df_numerical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   duration_ms       114000 non-null  int64
#  1   explicit          114000 non-null  bool
#  2   danceability      114000 non-null  float64
#  3   energy            114000 non-null  float64
#  4   key               114000 non-null  int64
#  5   loudness          114000 non-null  float64
#  6   mode              114000 non-null  int64
#  7   speechiness       114000 non-null  float64
#  8   acousticness      114000 non-null  float64
#  9   instrumentalness  114000 non-null  float64
#  10  liveness          114000 non-null  float64
#  11  valence           114000 non-null  float64
#  12  tempo             114000 non-null  float64
#  13  time_signature    114000 non-null  int64
#  14  track_genre       114000 non-null  object
#  15  time_signature    114000 non-null  int64
# dtypes: bool(1), float64(9), int64(5), object(1)
# memory usage: 13.2+ MB
#         duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 0            230666     False         0.676  0.4610    1    -6.746     0
# 1            149610     False         0.420  0.1660    1   -17.235     1
# 2            210826     False         0.438  0.3590    0    -9.734     1
# 3            201933     False         0.266  0.0596    0   -18.515     1
# 4            198853     False         0.618  0.4430    2    -9.681     1
# ...             ...       ...           ...     ...  ...       ...   ...
# 113995       384999     False         0.172  0.2350    5   -16.393     1
# 113996       385000     False         0.174  0.1170    0   -18.318     0
# 113997       271466     False         0.629  0.3290    0   -10.895     0
# 113998       283893     False         0.587  0.5060    7   -10.889     1
# 113999       241826     False         0.526  0.4870    1   -10.204     0
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# 0            0.1430        0.0322          0.000001    0.3580   0.7150
# 1            0.0763        0.9240          0.000006    0.1010   0.2670
# 2            0.0557        0.2100          0.000000    0.1170   0.1200
# 3            0.0363        0.9050          0.000071    0.1320   0.1430
# 4            0.0526        0.4690          0.000000    0.0829   0.1670
# ...             ...           ...               ...       ...      ...
# 113995       0.0422        0.6400          0.928000    0.0863   0.0339
# 113996       0.0401        0.9940          0.976000    0.1050   0.0350
# 113997       0.0420        0.8670          0.000000    0.0839   0.7430
# 113998       0.0297        0.3810          0.000000    0.2700   0.4130
# 113999       0.0725        0.6810          0.000000    0.0893   0.7080
#
#           tempo  time_signature  track_genre  time_signature
# 0        87.917               4     acoustic               4
# 1        77.489               4     acoustic               4
# 2        76.332               4     acoustic               4
# 3       181.740               3     acoustic               3
# 4       119.949               4     acoustic               4
# ...         ...             ...          ...             ...
# 113995  125.995               5  world-music               5
# 113996   85.239               4  world-music               4
# 113997  132.378               4  world-music               4
# 113998  135.960               4  world-music               4
# 113999   79.198               4  world-music               4
#
# [114000 rows x 16 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_cols_df = song_df.select_dtypes(include=['int64', 'float64'])
numeric_cols_df = numeric_cols_df[['popularity', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', "time_signature"]]
summary_statistics_df = numeric_cols_df.describe().transpose()
summary_statistics_df["deviations"] = (summary_statistics_df["max"] - summary_statistics_df["min"]) / summary_statistics_df["std"]
summary_statistics_df
# Out:
#                      count        mean        std     min       25%  \
# popularity        114000.0   33.238535  22.305078   0.000  17.00000
# danceability      114000.0    0.566800   0.173542   0.000   0.45600
# energy            114000.0    0.641383   0.251529   0.000   0.47200
# key               114000.0    5.309140   3.559987   0.000   2.00000
# loudness          114000.0   -8.258960   5.029337 -49.531 -10.01300
# mode              114000.0    0.637553   0.480709   0.000   0.00000
# speechiness       114000.0    0.084652   0.105732   0.000   0.03590
# acousticness      114000.0    0.314910   0.332523   0.000   0.01690
# instrumentalness  114000.0    0.156050   0.309555   0.000   0.00000
# liveness          114000.0    0.213553   0.190378   0.000   0.09800
# valence           114000.0    0.474068   0.259261   0.000   0.26000
# tempo             114000.0  122.147837  29.978197   0.000  99.21875
# time_signature    114000.0    3.904035   0.432621   0.000   4.00000
#
#                          50%       75%      max  deviations
# popularity         35.000000   50.0000  100.000    4.483284
# danceability        0.580000    0.6950    0.985    5.675854
# energy              0.685000    0.8540    1.000    3.975684
# key                 5.000000    8.0000   11.000    3.089899
# loudness           -7.004000   -5.0030    4.532   10.749529
# mode                1.000000    1.0000    1.000    2.080260
# speechiness         0.048900    0.0845    0.965    9.126818
# acousticness        0.169000    0.5980    0.996    2.995284
# instrumentalness    0.000042    0.0490    1.000    3.230445
# liveness            0.132000    0.2730    1.000    5.252716
# valence             0.464000    0.6830    0.995    3.837830
# tempo             122.017000  140.0710  243.372    8.118300
# time_signature      4.000000    4.0000    5.000   11.557464

# %%
from sklearn.preprocessing import RobustScaler
rs = RobustScaler()

songs_scaled = rs.fit_transform(numeric_cols_df)
user_scaled = rs.fit_transform(numeric_cols_df)
df_songs_scaled = pd.DataFrame(songs_scaled, columns=numeric_cols_df.columns)
df_songs_scaled
# Out:
#         popularity  danceability    energy       key  loudness  mode  \
# 0         1.151515      0.401674 -0.586387 -0.666667  0.051497  -1.0
# 1         0.606061     -0.669456 -1.358639 -0.666667 -2.042116   0.0
# 2         0.666667     -0.594142 -0.853403 -0.833333 -0.544910   0.0
# 3         1.090909     -1.313808 -1.637173 -0.833333 -2.297605   0.0
# 4         1.424242      0.158996 -0.633508 -0.500000 -0.534331   0.0
# ...            ...           ...       ...       ...       ...   ...
# 113995   -0.424242     -1.707113 -1.178010  0.000000 -1.874052   0.0
# 113996   -0.393939     -1.698745 -1.486911 -0.833333 -2.258283  -1.0
# 113997   -0.393939      0.205021 -0.931937 -0.833333 -0.776647  -1.0
# 113998    0.181818      0.029289 -0.468586  0.333333 -0.775449   0.0
# 113999   -0.393939     -0.225941 -0.518325 -0.666667 -0.638723  -1.0
#
#         speechiness  acousticness  instrumentalness  liveness   valence  \
# 0          1.936214     -0.235416         -0.000828  1.291429  0.593381
# 1          0.563786      1.299260         -0.000736 -0.177143 -0.465721
# 2          0.139918      0.070556         -0.000849 -0.085714 -0.813239
# 3         -0.259259      1.266563          0.000594  0.000000 -0.758865
# 4          0.076132      0.516262         -0.000849 -0.280571 -0.702128
# ...             ...           ...               ...       ...       ...
# 113995    -0.137860      0.810532         18.937927 -0.261143 -1.016785
# 113996    -0.181070      1.419721         19.917518 -0.154286 -1.014184
# 113997    -0.141975      1.201170         -0.000849 -0.274857  0.659574
# 113998    -0.395062      0.364825         -0.000849  0.788571 -0.120567
# 113999     0.485597      0.881088         -0.000849 -0.244000  0.576832
#
#            tempo  time_signature
# 0      -0.834715             0.0
# 1      -1.089977             0.0
# 2      -1.118298             0.0
# 3       1.461927            -1.0
# 4      -0.050621             0.0
# ...          ...             ...
# 113995  0.097375             1.0
# 113996 -0.900269             0.0
# 113997  0.253621             0.0
# 113998  0.341303             0.0
# 113999 -1.048143             0.0
#
# [114000 rows x 13 columns]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Initialize the MinMaxScaler
ms = MinMaxScaler()

# Assuming 'numeric_cols_df' is your dataframe with numeric columns
# Scale the data
songs_scaled = ms.fit_transform(numeric_cols_df)

# Convert the scaled data back into a dataframe
df_songs_scaled = pd.DataFrame(songs_scaled, columns=numeric_cols_df.columns)
df_songs_scaled = df_songs_scaled.dropna()

# Variables to hold the results
wcss = []
silhouette_scores = []

# Range of number of clusters
K = range(2, 40, 3)  # Adjust the range based on your specific needs

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_songs_scaled)
    wcss.append(kmeans.inertia_)
    labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(df_songs_scaled, labels))

# Plotting the Elbow Method graph
plt.figure(figsize=(12, 6))
plt.plot(K, wcss, 'bo-', markersize=8)
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# Plotting the Silhouette Score
plt.figure(figsize=(12, 6))
plt.plot(K, silhouette_scores, 'go-', markersize=8)
plt.title('Silhouette Score For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 30
#      28     wcss.append(kmeans.inertia_)
#      29     labels = kmeans.labels_
# ---> 30     silhouette_scores.append(silhouette_score(df_songs_scaled, labels))
#      32 # Plotting the Elbow Method graph
#      33 plt.figure(figsize=(12, 6))
#
# File /opt/homebrew/anaconda3/envs/econcs/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /opt/homebrew/anaconda3/envs/econcs/lib/python3.9/site-packages/sklearn/metrics/cluster/_unsupervised.py:140, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     138     else:
#     139         X, labels = X[indices], labels[indices]
# --> 140 return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#
# File /opt/homebrew/anaconda3/envs/econcs/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File /opt/homebrew/anaconda3/envs/econcs/lib/python3.9/site-packages/sklearn/metrics/cluster/_unsupervised.py:303, in silhouette_samples(X, labels, metric, **kwds)
#     299 kwds["metric"] = metric
#     300 reduce_func = functools.partial(
#     301     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     302 )
# --> 303 results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func, **kwds))
#     304 intra_clust_dists, inter_clust_dists = results
#     305 intra_clust_dists = np.concatenate(intra_clust_dists)
#
# File /opt/homebrew/anaconda3/envs/econcs/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:2144, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2142 else:
#    2143     X_chunk = X[sl]
# -> 2144 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    2145 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    2146     metric, None
#    2147 ) is euclidean_distances:
#    2148     # zeroing diagonal, taking care of aliases of "euclidean",
#    2149     # i.e. "l2"
#    2150     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File /opt/homebrew/anaconda3/envs/econcs/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File /opt/homebrew/anaconda3/envs/econcs/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:2331, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2328         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2329     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2331 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File /opt/homebrew/anaconda3/envs/econcs/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:1871, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1868 X, Y, dtype = _return_float_dtype(X, Y)
#    1870 if effective_n_jobs(n_jobs) == 1:
# -> 1871     return func(X, Y, **kwds)
#    1873 # enforce a threading backend to prevent data communication overhead
#    1874 fd = delayed(_dist_wrapper)
#
# File /opt/homebrew/anaconda3/envs/econcs/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File /opt/homebrew/anaconda3/envs/econcs/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:347, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     341     if Y_norm_squared.shape != (1, Y.shape[0]):
#     342         raise ValueError(
#     343             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     344             f"Y_norm_squared of shape {original_shape}."
#     345         )
# --> 347 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File /opt/homebrew/anaconda3/envs/econcs/lib/python3.9/site-packages/sklearn/metrics/pairwise.py:384, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     382     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     383     distances += XX
# --> 384     distances += YY
#     385 np.maximum(distances, 0, out=distances)
#     387 # Ensure that distances between vectors and themselves are set to 0.0.
#     388 # This may not be the case due to floating point rounding errors.
#
# KeyboardInterrupt:

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# Initialize the RobustScaler
ms = MinMaxScaler()

# Scale the data
songs_scaled = rs.fit_transform(numeric_cols_df)

# Convert the scaled data back into a dataframe
df_songs_scaled = pd.DataFrame(songs_scaled, columns=numeric_cols_df.columns)
df_songs_scaled  = df_songs_scaled.dropna()

# Perform K-means clustering
k = 20  # Number of clusters; adjust based on your analysis
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(df_songs_scaled)

# Assign the cluster labels to the scaled dataframe
df_songs_scaled['cluster'] = kmeans.labels_
df_songs_scaled

# Now, df_songs_scaled includes the cluster labels for each song
# Out:
#         popularity  danceability    energy       key  loudness  mode  \
# 0         1.151515      0.401674 -0.586387 -0.666667  0.051497  -1.0
# 1         0.606061     -0.669456 -1.358639 -0.666667 -2.042116   0.0
# 2         0.666667     -0.594142 -0.853403 -0.833333 -0.544910   0.0
# 3         1.090909     -1.313808 -1.637173 -0.833333 -2.297605   0.0
# 4         1.424242      0.158996 -0.633508 -0.500000 -0.534331   0.0
# ...            ...           ...       ...       ...       ...   ...
# 113995   -0.424242     -1.707113 -1.178010  0.000000 -1.874052   0.0
# 113996   -0.393939     -1.698745 -1.486911 -0.833333 -2.258283  -1.0
# 113997   -0.393939      0.205021 -0.931937 -0.833333 -0.776647  -1.0
# 113998    0.181818      0.029289 -0.468586  0.333333 -0.775449   0.0
# 113999   -0.393939     -0.225941 -0.518325 -0.666667 -0.638723  -1.0
#
#         speechiness  acousticness  instrumentalness  liveness   valence  \
# 0          1.936214     -0.235416         -0.000828  1.291429  0.593381
# 1          0.563786      1.299260         -0.000736 -0.177143 -0.465721
# 2          0.139918      0.070556         -0.000849 -0.085714 -0.813239
# 3         -0.259259      1.266563          0.000594  0.000000 -0.758865
# 4          0.076132      0.516262         -0.000849 -0.280571 -0.702128
# ...             ...           ...               ...       ...       ...
# 113995    -0.137860      0.810532         18.937927 -0.261143 -1.016785
# 113996    -0.181070      1.419721         19.917518 -0.154286 -1.014184
# 113997    -0.141975      1.201170         -0.000849 -0.274857  0.659574
# 113998    -0.395062      0.364825         -0.000849  0.788571 -0.120567
# 113999     0.485597      0.881088         -0.000849 -0.244000  0.576832
#
#            tempo  time_signature  cluster
# 0      -0.834715             0.0        0
# 1      -1.089977             0.0        5
# 2      -1.118298             0.0       12
# 3       1.461927            -1.0        5
# 4      -0.050621             0.0       12
# ...          ...             ...      ...
# 113995  0.097375             1.0        8
# 113996 -0.900269             0.0        8
# 113997  0.253621             0.0       11
# 113998  0.341303             0.0       12
# 113999 -1.048143             0.0       11
#
# [114000 rows x 14 columns]

# %%
df_songs_scaled['cluster'] = kmeans.labels_
df_songs_scaled['cluster'].value_counts().plot(kind='bar')
plt.xlabel('Cluster')
plt.ylabel('Amount of songs')
plt.title('Amount of songs per cluster')
plt.show()

# %%
song_df["cluster"] = df_songs_scaled['cluster']
song_df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                         track_name  popularity  duration_ms  explicit  \
# 0                           Comedy          73       230666     False
# 1                 Ghost - Acoustic          55       149610     False
# 2                   To Begin Again          57       210826     False
# 3       Can't Help Falling In Love          71       201933     False
# 4                          Hold On          82       198853     False
# ...                            ...         ...          ...       ...
# 113995         Sleep My Little Boy          21       384999     False
# 113996            Water Into Light          22       385000     False
# 113997              Miss Perfumado          22       271466     False
# 113998                     Friends          41       283893     False
# 113999                   Barbincor          22       241826     False
#
#         danceability  energy  ...  mode  speechiness  acousticness  \
# 0              0.676  0.4610  ...     0       0.1430        0.0322
# 1              0.420  0.1660  ...     1       0.0763        0.9240
# 2              0.438  0.3590  ...     1       0.0557        0.2100
# 3              0.266  0.0596  ...     1       0.0363        0.9050
# 4              0.618  0.4430  ...     1       0.0526        0.4690
# ...              ...     ...  ...   ...          ...           ...
# 113995         0.172  0.2350  ...     1       0.0422        0.6400
# 113996         0.174  0.1170  ...     0       0.0401        0.9940
# 113997         0.629  0.3290  ...     0       0.0420        0.8670
# 113998         0.587  0.5060  ...     1       0.0297        0.3810
# 113999         0.526  0.4870  ...     0       0.0725        0.6810
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.000001    0.3580   0.7150   87.917               4
# 1               0.000006    0.1010   0.2670   77.489               4
# 2               0.000000    0.1170   0.1200   76.332               4
# 3               0.000071    0.1320   0.1430  181.740               3
# 4               0.000000    0.0829   0.1670  119.949               4
# ...                  ...       ...      ...      ...             ...
# 113995          0.928000    0.0863   0.0339  125.995               5
# 113996          0.976000    0.1050   0.0350   85.239               4
# 113997          0.000000    0.0839   0.7430  132.378               4
# 113998          0.000000    0.2700   0.4130  135.960               4
# 113999          0.000000    0.0893   0.7080   79.198               4
#
#         track_genre  cluster
# 0          acoustic        0
# 1          acoustic        5
# 2          acoustic       12
# 3          acoustic        5
# 4          acoustic       12
# ...             ...      ...
# 113995  world-music        8
# 113996  world-music        8
# 113997  world-music       11
# 113998  world-music       12
# 113999  world-music       11
#
# [114000 rows x 22 columns]

# %%
song_df_clustered = song_df[['track_id', 'artists', 'album_name', 'track_name',
       'popularity', 'duration_ms', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
       'track_genre', 'cluster']]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named song_df
# First, let's generate summary statistics for the danceability value for each cluster

summary_stats = song_df.groupby('cluster')['danceability'].describe()
print(summary_stats)

# Now, let's plot the distribution of danceability values for each cluster

# Set the style of seaborn
sns.set(style="whitegrid")

# Initialize the matplotlib figure
plt.figure(figsize=(12, 6))

# Create a boxplot to show the distribution of danceability values for each cluster
sns.boxplot(x='cluster', y='danceability', data=song_df)

plt.title('Distribution of Danceability Value by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Danceability')

plt.show()
# Out:
#            count      mean       std     min      25%     50%      75%    max
# cluster
# 0         7451.0  0.632036  0.167188  0.0811  0.51550  0.6530  0.76100  0.978
# 1         3586.0  0.541115  0.194248  0.0000  0.40500  0.5675  0.69100  0.970
# 2        12028.0  0.664644  0.111359  0.2170  0.59000  0.6680  0.74300  0.971
# 3         3457.0  0.552888  0.177808  0.0000  0.43500  0.5650  0.68600  0.985
# 4          868.0  0.565597  0.089002  0.2520  0.50600  0.5655  0.62500  0.901
# 5         6834.0  0.446629  0.140046  0.0000  0.35300  0.4500  0.54300  0.889
# 6         2797.0  0.531752  0.192161  0.0000  0.40100  0.5520  0.67400  0.952
# 7         4772.0  0.673090  0.158196  0.0644  0.57300  0.6915  0.79200  0.981
# 8         3783.0  0.419279  0.201584  0.0000  0.25200  0.4150  0.57500  0.920
# 9         5217.0  0.515225  0.142876  0.0000  0.42100  0.5230  0.61200  0.977
# 10        9926.0  0.443258  0.117512  0.0679  0.36600  0.4485  0.52200  0.791
# 11        8395.0  0.684226  0.104530  0.3220  0.61200  0.6850  0.75400  0.980
# 12       10539.0  0.497533  0.119179  0.0629  0.41800  0.5070  0.58200  0.884
# 13        6308.0  0.601412  0.186261  0.0513  0.49175  0.6480  0.74800  0.983
# 14         644.0  0.538956  0.232213  0.0704  0.33400  0.5690  0.73225  0.982
# 15        2010.0  0.642901  0.156368  0.0565  0.54300  0.6520  0.75200  0.973
# 16        8965.0  0.559746  0.127207  0.0783  0.47900  0.5640  0.65100  0.965
# 17        2468.0  0.278832  0.150271  0.0000  0.16075  0.2630  0.39500  0.744
# 18        2741.0  0.542276  0.190916  0.0000  0.41300  0.5610  0.69200  0.969
# 19       11211.0  0.671679  0.118072  0.1390  0.58900  0.6780  0.75900  0.984

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df_songs_scaled' is your DataFrame and it contains a 'cluster' column
# Number of clusters - adjust this based on your actual number of clusters
num_clusters = song_df['cluster'].nunique()

# Set up the matplotlib figure
# Calculate the number of rows needed for subplots (up to 6 rows of 5 figures each)
rows = (num_clusters // 5) + (1 if num_clusters % 5 else 0)
rows = min(rows, 6)  # Limit to a maximum of 6 rows

fig, axes = plt.subplots(rows, 5, figsize=(20, rows*4))  # Adjust the figure size as needed
fig.tight_layout(pad=5.0)

# Flatten the axes array for easy indexing
axes = axes.flatten()

for i in range(num_clusters):
    cluster_data = song_df[song_df['cluster'] == i]['danceability']
    sns.histplot(cluster_data, ax=axes[i], kde=True)
    axes[i].set_title(f'Cluster {i} Danceability')
    axes[i].set_xlabel('Danceability')
    axes[i].set_ylabel('Frequency')

# Hide any unused subplots
for j in range(i+1, len(axes)):
    axes[j].set_visible(False)

plt.show()

# %%
import numpy as np

# Generate 10 non-zero entries that sum up to 1
non_zero_entries = np.random.dirichlet(np.ones(10), size=1)

# Create a vector of 20 entries with 10 zeros
vector = np.zeros(20)

# Choose 10 random indices from the vector where the non-zero entries will be placed
non_zero_indices = np.random.choice(range(20), size=10, replace=False)

# Place the non-zero entries in the vector
vector[non_zero_indices] = non_zero_entries

vector
# Out:
# array([0.00418077, 0.        , 0.10125948, 0.        , 0.0098969 ,
#        0.        , 0.        , 0.09113984, 0.        , 0.        ,
#        0.08543238, 0.        , 0.00711228, 0.19913152, 0.        ,
#        0.30554256, 0.12489547, 0.        , 0.        , 0.0714088 ])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'vector' is your previously generated vector of weights
# And 'df_songs_scaled' contains your cluster labels and 'danceability' values

# Calculate the total number of samples you want to draw
total_samples = 100000 # You can adjust this number based on your needs

# Create an empty list to store samples
new_distribution_samples = []

for i, weight in enumerate(vector):
    if weight > 0:  # Only sample from clusters with a non-zero weight
        # Calculate the number of samples to draw for this cluster
        num_samples = int(np.round(weight * total_samples))
        
        # Get the 'danceability' values for the current cluster
        cluster_danceability = df_songs_scaled[df_songs_scaled['cluster'] == i]['danceability']
        
        # Randomly sample from this cluster's 'danceability' values
        samples = np.random.choice(cluster_danceability, num_samples)
        
        # Append these samples to the list
        new_distribution_samples.extend(samples)

# Convert the list of samples into a numpy array
new_distribution_samples = np.array(new_distribution_samples)

# Plotting the new distribution
plt.figure(figsize=(10, 6))
plt.hist(new_distribution_samples, bins=60, alpha=0.7, color='blue')
plt.title('New Distribution of Danceability Based on Cluster Weights')
plt.xlabel('Danceability')
plt.ylabel('Frequency')
plt.show()

# %%
def compute_stats(df, parameters):
    """
    Compute the mean and standard deviation for specified parameters in a DataFrame.

    Parameters:
    - df: Pandas DataFrame containing the data.
    - parameters: List of strings, names of the columns for which to compute statistics.

    Returns:
    - A dictionary with each parameter as keys and their mean and standard deviation as values.
    """
    stats = {}
    for param in parameters:
        if param in df.columns:  # Check if the parameter is in the DataFrame
            mean = df[param].mean()
            std_dev = df[param].std()
            stats[param] = {'mean': mean, 'std_dev': std_dev}
        else:
            print(f"Warning: '{param}' not found in DataFrame columns.")

    return stats



def compute_cluster_weighted_parameters(song_df, track_ids, parameters):
    # Filter rows based on the provided track_ids
    filtered_df = song_df[song_df['track_id'].isin(track_ids)]
    
    # Count the occurrence of each cluster
    cluster_counts = filtered_df['cluster'].value_counts()
    
    # Compute the weight for each cluster
    cluster_weights = cluster_counts / len(track_ids)
    
    # Initialize a dictionary to store the computed means for each parameter
    parameter_means = {}
    
    for parameter in parameters:
        weighted_sum = 0
        total_weight = 0  # To account for clusters with 0 tracks
        
        for cluster, weight in cluster_weights.items():
            # Extract parameter values for the current cluster
            cluster_param_values = song_df[song_df['cluster'] == cluster][parameter]
            
            # Sample from this cluster's parameter values based on the weight
            # Here we assume the number of samples to draw proportional to the total weight
            if not cluster_param_values.empty:
                samples = np.random.choice(cluster_param_values, size=int(weight * 1000), replace=True)
                weighted_sum += np.mean(samples) * weight
                total_weight += weight
        
        # Compute the weighted mean for the parameter
        if total_weight > 0:
            parameter_means[parameter] = weighted_sum / total_weight
        else:
            parameter_means[parameter] = None  # No data for this parameter

    keys_to_drop = ['key', 'time_signature', 'mode', 'popularity']
    keys = set(parameter_means.keys()).difference(set(keys_to_drop))


    modified_input_parameters = {key: value for key, value in parameter_means.items() if key not in keys_to_drop}

    # for key in keys:
    #     if key == 'tempo':
    #         continue 
        
    #     modified_input_parameters.update({'min_' + key : parameter_means[key] - 0.1})
    #     modified_input_parameters.update({'max_' + key : parameter_means[key] + 0.1})
    
    return modified_input_parameters

# List of parameters to compute weighted means for
parameters = ['danceability', 'energy',
              'loudness', 'speechiness', 'acousticness',
              'instrumentalness', 'liveness', 'valence', 'tempo']

# Example usage
track_ids = ['5SuOikwiRyPMVoIQDJUgSV', '4qPNDBW1i3p13qLCt0Ki3A', '1iJBSr7s7jYXzM8EGcbK5b']  # Add more track_ids as needed
weighted_parameter_means = compute_cluster_weighted_parameters(song_df, track_ids, parameters)

print(weighted_parameter_means)
# Out:
# {'danceability': 0.5611411224749558, 'energy': 0.5743078052116954, 'loudness': -8.570689001400929, 'speechiness': 0.10784133845559199, 'acousticness': 0.4177204730168771, 'instrumentalness': 0.005567393290665008, 'liveness': 0.17371578026424234, 'valence': 0.44155778135975426, 'tempo': 121.05955511368185}

# %%
import spotipy
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from scipy.stats import norm
import time 
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import urllib3


session = requests.Session()
retry = urllib3.Retry(
    respect_retry_after_header=False
)
adapter = requests.adapters.HTTPAdapter(max_retries=retry)

SPOTIPY_CLIENT_ID = "83cd5597206f4c43a0ca1688217a235c"
SPOTIPY_CLIENT_SECRET = "359d44eb35454d9ab4dec39cf8d4324f"

client_credentials_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(auth='BQAtYJaX7UzzJgNtlkqKV1XUHzRuSkkt8cYhWBnv2JcCWlwmYTyKHMZCuuDrrhhFW-Z5ouFVxOIJcHw3W_Ygjgmy8BiaBcun6yL-Glgvx0JGFL3hlVg',retries=0, client_credentials_manager=client_credentials_manager, requests_session=session)

# %%
def generate_random_feature_value(center, stddev=0.05, feature_type='continuous'):
    if feature_type == 'continuous':
        return np.random.normal(loc=center, scale=stddev)
    elif feature_type == 'discrete':
        return int(np.round(np.random.normal(loc=center, scale=stddev)))
    else:
        raise ValueError("Invalid feature_type. Choose 'continuous' or 'discrete'.")

def calculate_likelihood(value, center, stddev=0.05, feature_type='continuous'):
    """
    Calculate the likelihood of a given value in a specified normal distribution.

    Parameters:
    - value: The value for which to calculate the likelihood.
    - center: The mean (center) of the distribution.
    - stddev: The standard deviation of the distribution. Default is 0.05.
    - feature_type: The type of feature ('continuous' or 'discrete').

    Returns:
    - The likelihood (density) of the given value in the distribution.
    """
    if feature_type == 'continuous':
        # For continuous features, directly use the PDF of the normal distribution.
        likelihood = norm.pdf(value, loc=center, scale=stddev)
    elif feature_type == 'discrete':
        # For discrete features, calculate the PDF at the nearest integer.
        discrete_value = int(np.round(value))
        likelihood = norm.pdf(discrete_value, loc=center, scale=stddev)
    else:
        raise ValueError("Invalid feature_type. Choose 'continuous' or 'discrete'.")
    
    return likelihood

# function to generate a random value for each feature
def generate_random_feature_values(centers, std_devs):
    random_values = {}
    for feature, center in centers.items():
        feature_type = 'discrete' if feature in ['key', 'mode'] else 'continuous'
        random_values[feature] = generate_random_feature_value(center, stddev=std_devs[feature], feature_type=feature_type)
    return random_values


def calculate_all_log_likelihoods(centers, std_devs, values):
    """
    Assuming that all features are independent, calculate the likelihood of the current value. 
    """
    total_likelihood = 1
    for feature, center in centers.items():
        feature_type = 'discrete' if feature in ['key', 'mode'] else 'continuous'
        curr_likelihood = calculate_likelihood(value=values[feature], center=center, stddev=std_devs[feature], feature_type=feature_type)
        total_likelihood += (np.log(curr_likelihood))
    
    return total_likelihood


def calculate_log_likelihood_for_row(row, true_centers, std_devs):
    values = {feature: row[feature] for feature in true_centers.keys()}
    return calculate_all_log_likelihoods(true_centers, std_devs, values)

# %%
genre_set = ['acoustic', 'folk', 'pop', 'rock-n-roll']
# true_centers = {
#     'acousticness': 0.5,
#     'danceability': 0.5,
#     'energy': 0.5,
#     'instrumentalness': 0.5,
#     # 'key': 5,  # Discrete
#     'liveness': 0.5,
#     'loudness': -5.0,
#     'speechiness': 0.5,
#     'tempo': 120,
#     'valence': 0.5
#     # 'mode': 0,  # Discrete, binary
#     # 'popularity': 50  # Assuming a median popularity for demonstration
# }

# std_devs = {
#     'acousticness': 0.05,
#     'danceability': 0.05,
#     'energy': 0.05,
#     'instrumentalness': 0.01,
#     # 'key': 1,  # Discrete, but simulated with spread
#     'liveness': 0.05,
#     'loudness': 2.0,
#     'speechiness': 0.01,
#     'tempo': 10,
#     'valence': 0.05
#     # 'mode': 0.5,  # Not applicable for binary, but included for consistency
#     # 'popularity': 10
# }

stats = compute_stats(song_df, parameters)
true_centers = {param : value['mean'] for param, value in stats.items()}
std_devs = {param : value['std_dev'] for param, value in stats.items()}

# %%
# Calculate log likelihood for each row and create a new column with those values
song_df['log_likelihood'] = song_df.apply(lambda row: calculate_log_likelihood_for_row(row, true_centers, std_devs), axis=1)
song_df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  speechiness  acousticness  instrumentalness  \
# 0         0.676  0.4610  ...       0.1430        0.0322          0.000001
# 1         0.420  0.1660  ...       0.0763        0.9240          0.000006
# 2         0.438  0.3590  ...       0.0557        0.2100          0.000000
# 3         0.266  0.0596  ...       0.0363        0.9050          0.000071
# 4         0.618  0.4430  ...       0.0526        0.4690          0.000000
#
#    liveness  valence    tempo  time_signature  track_genre  cluster  \
# 0    0.3580    0.715   87.917               4     acoustic        0
# 1    0.1010    0.267   77.489               4     acoustic        5
# 2    0.1170    0.120   76.332               4     acoustic       12
# 3    0.1320    0.143  181.740               3     acoustic        5
# 4    0.0829    0.167  119.949               4     acoustic       12
#
#    log_likelihood
# 0      -13.843666
# 1      -16.770318
# 2      -13.485701
# 3      -24.063436
# 4      -12.850339
#
# [5 rows x 23 columns]

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=song_df, x='cluster', y='log_likelihood', palette='viridis', hue='cluster', style='cluster')
plt.title('Log Likelihood by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Log Likelihood')
plt.legend(title='Cluster', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
top_50_tracks_df = song_df.sort_values(by='log_likelihood', ascending=False).head(50)
top_50_tracks_df.tail()
# Out:
#         Unnamed: 0                track_id           artists  \
# 84178        84178  26g90nfKw79y5ZcRRqHLCz        Cem Karaca
# 90288        90288  2vVqZQifzXZY6j3buwnhPC  Gualberto Castro
# 82712        82712  5kCjHUh0QdbANYM0ZVlLVO          The Cars
# 26804        26804  5GGtoBwQtvoXRvfeKBToG1   Pedro Gonçalves
# 102614      102614  1ODitWwCi2P2D489FX5CmY     Jasleen Royal
#
#                                                album_name  \
# 84178                                            Haykırış
# 90288   La Gran Coleccion Del 60 Aniversario CBS - Gua...
# 82712                      Shake It Up (Expanded Edition)
# 26804                                       Chama Por Mim
# 102614         Jahaan Tu Chala - Midnight Mix (Gully Boy)
#
#                                         track_name  popularity  duration_ms  \
# 84178                                     Çökertme          43       181973
# 90288                                 La Felicidad          35       212960
# 82712                              Midnight Dancer          23       262146
# 26804                                Chama Por Mim          19       189428
# 102614  Jahaan Tu Chala - Midnight Mix (Gully Boy)          36       170029
#
#         explicit  danceability  energy  ...  speechiness  acousticness  \
# 84178      False         0.629   0.521  ...       0.0378         0.285
# 90288      False         0.536   0.468  ...       0.0369         0.461
# 82712      False         0.691   0.592  ...       0.0290         0.353
# 26804      False         0.656   0.633  ...       0.0375         0.367
# 102614     False         0.559   0.672  ...       0.0417         0.170
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 84178           0.000000     0.125    0.615  124.178               4
# 90288           0.000002     0.161    0.461  134.422               4
# 82712           0.223000     0.188    0.347  113.324               4
# 26804           0.000002     0.179    0.473  139.899               4
# 102614          0.000238     0.190    0.537  115.160               4
#
#         track_genre  cluster  log_likelihood
# 84178    psych-rock       11       -9.215348
# 90288   rock-n-roll       12       -9.217048
# 82712     power-pop        3       -9.223608
# 26804        disney       19       -9.226948
# 102614   songwriter       12       -9.230821
#
# [5 rows x 23 columns]

# %%
user_likes_songs = top_50_tracks_df.sample(n=10)

accept_set = list(user_likes_songs['track_id'])[:5]
user_likes_songs
# Out:
#        Unnamed: 0                track_id  \
# 26804       26804  5GGtoBwQtvoXRvfeKBToG1
# 84372       84372  0IbxYezgSiAdgYkFe478RG
# 63517       63517  0b6YJvYoOLT6aXWru8ckDX
# 84178       84178  26g90nfKw79y5ZcRRqHLCz
# 9679         9679  18sMrc6WLXCCxG1i8BLpCz
# 92215       92215  0b6YJvYoOLT6aXWru8ckDX
# 74728       74728  3dzMSEy7d8NEdfeLqe2zdW
# 40184       40184  18sMrc6WLXCCxG1i8BLpCz
# 74410       74410  4ZBxAQzSqxf09s3ef1KBf7
# 96918       96918  0jFT8rusCXzDuTTcgIFlRV
#
#                                           artists  \
# 26804                             Pedro Gonçalves
# 84372                                  Cem Karaca
# 63517                              Eikichi Yazawa
# 84178                                  Cem Karaca
# 9679                                 Palavrantiga
# 92215                              Eikichi Yazawa
# 74728  Liniker e os Caramelows;Liniker;Caramelows
# 40184                                Palavrantiga
# 74410                  Seu Pereira e Coletivo 401
# 96918                               Almir Guineto
#
#                                 album_name               track_name  \
# 26804                        Chama Por Mim            Chama Por Mim
# 84372           Cem Karaca Anısına, Vol. 3                 Çökertme
# 63517  MARIA (50th Anniversary Remastered)  MARIA - Remastered 2022
# 84178                             Haykırış                 Çökertme
# 9679                    Esperar é Caminhar          Vem Me Socorrer
# 92215  MARIA (50th Anniversary Remastered)  MARIA - Remastered 2022
# 74728                              Remonta                     Caeu
# 40184                   Esperar é Caminhar          Vem Me Socorrer
# 74410           Seu Pereira e Coletivo 401                   Já Era
# 96918                                  Pés          Brilho No Olhar
#
#        popularity  duration_ms  explicit  danceability  energy  ...  \
# 26804          19       189428     False         0.656   0.633  ...
# 84372          34       181973     False         0.622   0.522  ...
# 63517          35       206706     False         0.650   0.645  ...
# 84178          43       181973     False         0.629   0.521  ...
# 9679           45       334622     False         0.552   0.574  ...
# 92215          35       206706     False         0.650   0.645  ...
# 74728          41       262893     False         0.629   0.544  ...
# 40184          45       334622     False         0.552   0.574  ...
# 74410          43       263040     False         0.640   0.659  ...
# 96918          35       247666     False         0.500   0.685  ...
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 26804       0.0375         0.367          0.000002     0.179    0.473
# 84372       0.0368         0.316          0.000001     0.126    0.570
# 63517       0.0298         0.125          0.000000     0.217    0.527
# 84178       0.0378         0.285          0.000000     0.125    0.615
# 9679        0.0371         0.387          0.000000     0.178    0.486
# 92215       0.0298         0.125          0.000000     0.217    0.527
# 74728       0.0483         0.269          0.000000     0.119    0.469
# 40184       0.0371         0.387          0.000000     0.178    0.486
# 74410       0.0385         0.194          0.000000     0.167    0.382
# 96918       0.0369         0.501          0.000000     0.233    0.462
#
#          tempo  time_signature  track_genre  cluster  log_likelihood
# 26804  139.899               4       disney       19       -9.226948
# 84372  124.278               4   psych-rock       11       -9.021848
# 63517  103.696               4       j-rock       11       -9.186417
# 84178  124.178               4   psych-rock       11       -9.215348
# 9679   105.980               4       brazil       12       -9.076196
# 92215  103.696               4   rockabilly       11       -9.186417
# 74728  135.040               4          mpb        2       -9.207543
# 40184  105.980               4       gospel       12       -9.076196
# 74410  127.078               4          mpb       12       -9.109870
# 96918  135.851               4        samba       12       -9.203991
#
# [10 rows x 23 columns]

# %% [markdown]
# ## SIMULATION FOR CURRENT REC SYS.

# %%
average_lst = []

for i in range(100):
    time.sleep(1)
    recommendations = sp.recommendations(seed_tracks=accept_set, limit=10)

    # Sanity Clear...
    track_ids = []
    track_ids = [track['id'] for track in recommendations['tracks']]
    print(f"AT ITERATION {i}, TRACK_IDS: {len(track_ids)}")
    
    # Fetch audio features for these tracks
    audio_features = sp.audio_features(track_ids)

    track_likelihoods = []

    # Print out a vector of features for each track
    for track, features in zip(recommendations['tracks'], audio_features):
        track_name = track['name']
        features_vector = {
            'acousticness' : features['acousticness'],
            'danceability' : features['danceability'],
            'energy' : features['energy'],
            'instrumentalness' : features['instrumentalness'],
            'liveness' : features['liveness'],
            'loudness' : features['loudness'],
            'speechiness' : features['speechiness'],
            'tempo' : features['tempo'],
            'valence' : features['valence']
            # features['popularity']
        }
        
        # difference = np.linalg.norm(np.array(features_vector) - np.array(list(random_feature_values_scaled.values())))
        # if difference < 0.5: 
        #     accept_set.append(track['id'])
        likelihood = calculate_all_log_likelihoods(values=features_vector, centers=true_centers, std_devs=std_devs)
        track_likelihoods.append((track['id'], likelihood))
        # print(f"Track: {track_name} - Features Likelihood: {likelihood}")
        # print(f"Track: {track_name} - Features Vector: {features_vector}")
        
    track_likelihoods.sort(key=lambda x: x[1], reverse=True)
    
    top_five_tracks = track_likelihoods[:5]
    top_five_likelihoods = [likelihood for _, likelihood in top_five_tracks]
    
    average_lst.append(np.mean(top_five_likelihoods))
    accept_set = [track_id for track_id, _ in top_five_tracks]

plt.plot(average_lst)
# Out:
# AT ITERATION 0, TRACK_IDS: 10
# AT ITERATION 1, TRACK_IDS: 10
# AT ITERATION 2, TRACK_IDS: 10
# AT ITERATION 3, TRACK_IDS: 10
# AT ITERATION 4, TRACK_IDS: 10
# AT ITERATION 5, TRACK_IDS: 10
# AT ITERATION 6, TRACK_IDS: 10
# AT ITERATION 7, TRACK_IDS: 10
# AT ITERATION 8, TRACK_IDS: 10
# AT ITERATION 9, TRACK_IDS: 10
# AT ITERATION 10, TRACK_IDS: 10
# AT ITERATION 11, TRACK_IDS: 10
# AT ITERATION 12, TRACK_IDS: 10
# AT ITERATION 13, TRACK_IDS: 10
# AT ITERATION 14, TRACK_IDS: 10
# AT ITERATION 15, TRACK_IDS: 10
# AT ITERATION 16, TRACK_IDS: 10
# AT ITERATION 17, TRACK_IDS: 10
# AT ITERATION 18, TRACK_IDS: 10
# AT ITERATION 19, TRACK_IDS: 10
# AT ITERATION 20, TRACK_IDS: 10
# AT ITERATION 21, TRACK_IDS: 10
# AT ITERATION 22, TRACK_IDS: 10
# AT ITERATION 23, TRACK_IDS: 10
# AT ITERATION 24, TRACK_IDS: 10
# AT ITERATION 25, TRACK_IDS: 10
# AT ITERATION 26, TRACK_IDS: 10
# AT ITERATION 27, TRACK_IDS: 10
# AT ITERATION 28, TRACK_IDS: 10
# AT ITERATION 29, TRACK_IDS: 10
# AT ITERATION 30, TRACK_IDS: 10
# AT ITERATION 31, TRACK_IDS: 10
# AT ITERATION 32, TRACK_IDS: 10
# AT ITERATION 33, TRACK_IDS: 10
# AT ITERATION 34, TRACK_IDS: 10
# AT ITERATION 35, TRACK_IDS: 10
# AT ITERATION 36, TRACK_IDS: 10
# AT ITERATION 37, TRACK_IDS: 10
# AT ITERATION 38, TRACK_IDS: 10
# AT ITERATION 39, TRACK_IDS: 10
# AT ITERATION 40, TRACK_IDS: 10
# AT ITERATION 41, TRACK_IDS: 10
# AT ITERATION 42, TRACK_IDS: 10
# AT ITERATION 43, TRACK_IDS: 10
# AT ITERATION 44, TRACK_IDS: 10
# AT ITERATION 45, TRACK_IDS: 10
# AT ITERATION 46, TRACK_IDS: 10
# AT ITERATION 47, TRACK_IDS: 10
# AT ITERATION 48, TRACK_IDS: 10
# AT ITERATION 49, TRACK_IDS: 10
# AT ITERATION 50, TRACK_IDS: 10
# AT ITERATION 51, TRACK_IDS: 10
# AT ITERATION 52, TRACK_IDS: 10
# AT ITERATION 53, TRACK_IDS: 10
# AT ITERATION 54, TRACK_IDS: 10
# AT ITERATION 55, TRACK_IDS: 10
# AT ITERATION 56, TRACK_IDS: 10
# AT ITERATION 57, TRACK_IDS: 10
# AT ITERATION 58, TRACK_IDS: 10
# AT ITERATION 59, TRACK_IDS: 10
# AT ITERATION 60, TRACK_IDS: 10
# AT ITERATION 61, TRACK_IDS: 10
# AT ITERATION 62, TRACK_IDS: 10
# AT ITERATION 63, TRACK_IDS: 10
# AT ITERATION 64, TRACK_IDS: 10
# AT ITERATION 65, TRACK_IDS: 10
# AT ITERATION 66, TRACK_IDS: 10
# AT ITERATION 67, TRACK_IDS: 10
# AT ITERATION 68, TRACK_IDS: 10
# AT ITERATION 69, TRACK_IDS: 10
# AT ITERATION 70, TRACK_IDS: 10
# AT ITERATION 71, TRACK_IDS: 10
# AT ITERATION 72, TRACK_IDS: 10
# AT ITERATION 73, TRACK_IDS: 10
# AT ITERATION 74, TRACK_IDS: 10
# AT ITERATION 75, TRACK_IDS: 10
# AT ITERATION 76, TRACK_IDS: 10
# AT ITERATION 77, TRACK_IDS: 10
# AT ITERATION 78, TRACK_IDS: 10
# AT ITERATION 79, TRACK_IDS: 10
# AT ITERATION 80, TRACK_IDS: 10
# AT ITERATION 81, TRACK_IDS: 10
# AT ITERATION 82, TRACK_IDS: 10
# AT ITERATION 83, TRACK_IDS: 10
# AT ITERATION 84, TRACK_IDS: 10
# AT ITERATION 85, TRACK_IDS: 10
# AT ITERATION 86, TRACK_IDS: 10
# AT ITERATION 87, TRACK_IDS: 10
# AT ITERATION 88, TRACK_IDS: 10
# AT ITERATION 89, TRACK_IDS: 10
# AT ITERATION 90, TRACK_IDS: 10
# AT ITERATION 91, TRACK_IDS: 10
# AT ITERATION 92, TRACK_IDS: 10
# AT ITERATION 93, TRACK_IDS: 10
# AT ITERATION 94, TRACK_IDS: 10
# AT ITERATION 95, TRACK_IDS: 10
# AT ITERATION 96, TRACK_IDS: 10
# AT ITERATION 97, TRACK_IDS: 10
# AT ITERATION 98, TRACK_IDS: 10
# AT ITERATION 99, TRACK_IDS: 10

# %%
user_likes_songs_lst = list(user_likes_songs['track_id'])
user_likes_songs_lst
# Out:
# ['5GGtoBwQtvoXRvfeKBToG1',
#  '0IbxYezgSiAdgYkFe478RG',
#  '0b6YJvYoOLT6aXWru8ckDX',
#  '26g90nfKw79y5ZcRRqHLCz',
#  '18sMrc6WLXCCxG1i8BLpCz',
#  '0b6YJvYoOLT6aXWru8ckDX',
#  '3dzMSEy7d8NEdfeLqe2zdW',
#  '18sMrc6WLXCCxG1i8BLpCz',
#  '4ZBxAQzSqxf09s3ef1KBf7',
#  '0jFT8rusCXzDuTTcgIFlRV']

# %%
input_parameters = compute_cluster_weighted_parameters(song_df, user_likes_songs_lst, parameters)
input_parameters
# Out:
# {'danceability': 0.60364,
#  'energy': 0.5306808333333333,
#  'loudness': -8.762639999999998,
#  'speechiness': 0.04403716666666666,
#  'acousticness': 0.45707227233333325,
#  'instrumentalness': 0.003600177541666666,
#  'liveness': 0.1424373,
#  'valence': 0.5216951666666665,
#  'tempo': 114.84481416666664}

# %%
average_lst = []
recommendations = sp.recommendations(seed_genres=['pop', 'classical', 'rock', 'folk', 'jazz'], limit=10, **input_parameters)

# Sanity Clear...
track_ids = []
track_ids = [track['id'] for track in recommendations['tracks']]

# Fetch audio features for these tracks
audio_features = sp.audio_features(track_ids)

track_likelihoods = []

# Print out a vector of features for each track
for track, features in zip(recommendations['tracks'], audio_features):
    track_name = track['name']
    features_vector = {
        'acousticness' : features['acousticness'],
        'danceability' : features['danceability'],
        'energy' : features['energy'],
        'instrumentalness' : features['instrumentalness'],
        'liveness' : features['liveness'],
        'loudness' : features['loudness'],
        'speechiness' : features['speechiness'],
        'tempo' : features['tempo'],
        'valence' : features['valence']
        # features['popularity']
    }
    
    # difference = np.linalg.norm(np.array(features_vector) - np.array(list(random_feature_values_scaled.values())))
    # if difference < 0.5: 
    #     accept_set.append(track['id'])
    likelihood = calculate_all_log_likelihoods(values=features_vector, centers=true_centers, std_devs=std_devs)
    track_likelihoods.append((track['id'], likelihood))
    print(likelihood)
    # print(f"Track: {track_name} - Features Likelihood: {likelihood}")
    # print(f"Track: {track_name} - Features Vector: {features_vector}")
    
track_likelihoods.sort(key=lambda x: x[1], reverse=True)

top_five_tracks = track_likelihoods[:5]
top_five_likelihoods = [likelihood for _, likelihood in top_five_tracks]

average_lst.append(np.mean(top_five_likelihoods))
accept_set = [track_id for track_id, _ in top_five_tracks]
print(average_lst)
# Out:
# -3.5047723679990526
# -5.451972931672639
# -16.9755608656549
# -8.868049329369748
# -4.629853305237315
# -6.570112408018132
# -3.0647364453584305
# -3.1685488465841742
# -14.90395926817872
# -3.7673000590282557
# [-3.6270422048414455]
